# %% [markdown]
# # Importing the neccessary Libraries

# %%
import os
import uuid
import base64
from dotenv import load_dotenv

#libraries for the scanned textbooks
import fitz
import pytesseract
from PIL import Image

#Langchain libraries
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_classic.chains import create_retrieval_chain
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_groq import ChatGroq
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.documents import Document

# %%
load_dotenv()
# Out:
# True

# %%
import sys

# Adds the parent directory (MB_ASSISTANT) to the system path
sys.path.append(os.path.abspath('..'))

# %% [markdown]
# Let us load the scanned copies
# -----------------------------------------------
# PyMuPixmap to PIL
# 1. fitz opens the PDF and takes a "screenshot" (pixmap) of the page.
# 2. We convert that raw screenshot into a standard PIL Image.
# 3. We hand the PIL Image to Tesseract to read the words.
# -----------------------------------------------------------

# %%
#Instantiating pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
# Define function to load scanned textbooks
def extract_scanned_textbooks(pdf_path):
    """
    this function uses PyMuPDf (fitz) and Tesseract to convert scanned pdfs to texts
    """
    print(f"Opening {pdf_path} with PyMuPDF...")
    doc = fitz.open(pdf_path)
    docs = []

    for page_num, page in enumerate(doc):
        if page_num % 200 == 0:
            print(f"Processed {page_num} pages...")

        # Take High Resolution Screenshot of the page (matrix scales it up for better OCR reading)
        pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))
        
        #Convert to PIL image for Tesseract
        img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)

        #Extract text using Tesseract
        extracted_text = pytesseract.image_to_string(img)

        #keeping only pages that have text
        if extracted_text.strip():
            docs.append(
                Document(
                    page_content=extracted_text,
                    #Include source
                    metadata={
                        "source": pdf_path, 
                        "page": page_num + 1, 
                        "type": "ocr_text"
                        }
                )
            )
    
    return docs

# %%
# let's define a function to load all the pdfs from our scanned textbooks directory
def load_scanned_directory(directory_path):
    """
    Acts as a pdf Directory loader for the scanned OCR pdfs.
    loops through the folder and processes every pdf it finds.
    """
    all_scanned_docs = []

    for filename in os.listdir(directory_path):
        #combine folder path and file name
        full_file_path = os.path.join(directory_path, filename)
        print(f"\n Starting OCR on Textbook: {filename}")

        #use the PyMuPDF function
        book_docs = extract_scanned_textbooks(full_file_path)

        #add this book's pages  to out master list
        all_scanned_docs.extend(book_docs)
    
    return all_scanned_docs

# %%
#This should work, but it will take a lot of time, so i might just try using paddle OCR on colab and use T4 GPU
# Let's load the scanned textbooks
folder = r"data\scanned_textbooks"

# Check if the variable exists in memory AND is not empty
if 'total_scanned_docs' in locals() and total_scanned_docs:
    print(f"Skipping OCR... {len(total_scanned_docs)} pages already exist in memory!")
else:
    print("Starting Batch OCR Process....")
    total_scanned_docs = load_scanned_directory(folder)
    print(f"\n Batch Complete! Extracted a total of {len(total_scanned_docs)} pages across all textbooks.")

# %%
# Define exactly where you want the final text file saved
output_filepath = r"data\scanned_textbooks\extracted_board_prep.txt"

print(f"Writing {len(total_scanned_docs)} pages to local text file...")

# Open the file in write mode ('w') with utf-8 encoding to prevent character crashes
with open(output_filepath, "w", encoding="utf-8") as f:
    
    for doc in total_scanned_docs:
        # 1. Safely extract the tracking data from the metadata dictionary
        source_name = doc.metadata.get("source", "Unknown_Source")
        page_num = doc.metadata.get("page", "Unknown")
        
        # 2. Write a clear header so LangChain can chunk it easily later
        f.write(f"\n\n--- SOURCE: {source_name} | PAGE: {page_num} ---\n\n")
        
        # 3. Write the actual medical text extracted by Tesseract
        f.write(doc.page_content)

print(f"✅ Success! All OCR text saved locally to: {output_filepath}")

# %% [markdown]
# Let's use the multimodal method to extract the slides.
# ----------------------------------------------------

# %%
from langchain_core.messages import HumanMessage
from src.config import vision_model, llm

vision_llm = ChatGroq(
    model = vision_model,
    api_key = os.getenv("GROQ_API_KEY"),
    temperature = 0,
    max_retries=3
)

# %%
#define fuction to summarize images/diagrams
from src.prompts import VISION_LLM_PROMPT

def summarize_medical_diagram(image_bytes):
    """
    Sends the extracted image to Langchain's ChatGroq (vision_llm) for summary.
    """
    base64_img = base64.b64encode(image_bytes).decode('utf-8')

    try:
        #multimodal human message
        message = HumanMessage(
            content=[
                {
                    "type": "text",
                    "text": VISION_LLM_PROMPT
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_img}"
                    }
                }
            ]
        )
        response = vision_llm.invoke([message])
        return response.content
    
    except Exception as e:
        print(f"Vision Model Error: {e}")
        return "Image description failed due to API error"

# %% [markdown]
# Have to skip this because of Groq's token limit..
# Switching to a page by page processing, so that I can continue from where I stop or where limit was reached

# %%
import time
#Define slides processing function
def process_slides(pdf_path):
    """
    Extracts both the text and Langchain-summarized images from a slide deck.
    """
    print(f"\n Opening Slide Deck: {os.path.basename(pdf_path)}")
    doc = fitz.open(pdf_path)
    slide_docs = []

    for page_num, page in enumerate(doc):
        #extract text 
        page_text = page.get_text()
        if page_text.strip():
            slide_docs.append(
                Document(
                    page_content=page_text,
                    metadata={
                        "source": os.path.basename(pdf_path),
                        "page": page_num +1,
                        "type": "slide_text"
                    }
                )
            )
        
        #Extract images and pass to model
        image_list = page.get_images(full=True)
        if image_list:
            if page_num % 100 == 0:
                print(f" found {len(image_list)} image(s) on page {page_num + 1}. Calling Vision AI")

            for img_index, img in enumerate(image_list):
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]

                #call summarize function
                image_description = summarize_medical_diagram(image_bytes)

                #append to slide docs
                slide_docs.append(
                    Document(
                        page_content=f"IMAGE DESCRIPTION: {image_description}",
                        metadata={"source": os.path.basename(pdf_path), "page": page_num + 1, "type": "slide_image"}
                    )
                )

                #delay api calls for 2 seconds
                time.sleep(2)

# %%
#processing for each file in the dorectory
def batch_process_slides(directory_path, output_filepath):
    """
    Processes slides incrementally. Safe to stop and restart at any time.
    """
    all_slide_docs = []

    for filename in os.listdir(directory_path):
        if filename.endswith(".pdf"):
            full_path = os.path.join(directory_path, filename)
            docs = process_slides(full_path)
            all_slide_docs.extend(docs)

    os.makedirs9os.path.dirname(output_filepath, exist_ok=True)
    with open(output_filepath, "w", encoding="utf-8") as f:
        for doc in all_slide_docs:
            source = doc.metadata.get("source", "Unknow_Slide")
            page = doc.metadata.get("page", "Unknown")
            doc_type = doc.metadata.get("type", "Unknown_Type")

            f.write(f"\n\n--- SOURCE: {source} | PAGE: {page} | TYPE: {doc_type} ---\n\n")
            f.write(doc.page_content)
        
    print(f"\n Success! All multimodal slide data are saved to: {output_filepath}")
    return all_slide_docs

# %%
#get all the slides as txt
slides_folder = r"C:\Users\Loba\MB_ASSISTANT\data\slides"
output_text_file = r"C:\Users\Loba\MB_ASSISTANT\data\slidesextracted_slides.txt"

if os.path.exists(output_text_file):
    print(f"Skipping extraction. File already exists at: {output_text_file}")
else:
    print("Starting Multimodal Slide Extraction with LangChain...")
    extracted_slides = batch_process_slides(slides_folder, output_text_file)

# %% [markdown]
# # Page by Page Processing
# Due to free tier token limits, there is a need to save in batches so that you can pick up from last saved batch

# %%
import time

def get_page_level_progress(output_filepath):
    """
    Scans the text file and finds the highest page completed for each pdf.
    """
    progress = {}
    if os.path.exists(output_filepath):
        with open(output_filepath, "r", encoding="utf-8") as f:
            for line in f:
                if line.startswith("--- SOURCE:"):
                    parts = line.split("|")
                    if len(parts) >= 2:
                        source_part = parts[0].replace("--- SOURCE:", "").strip()
                        page_part = parts[1].replace("PAGE:", "").strip()
                        try:
                            page_num = int(page_part)
                            if source_part not in progress or page_num > progress[source_part]:
                                progress[source_part] = page_num
                        except ValueError:
                            pass
    return progress

# %%
#Process and saves slides per page

def process_and_save_slides(pdf_path, output_filepath, start_page=0):
    """
    Processes a slide deck and saves EVERY SINGLE PAGE to disk instantly.
    """
    filename = os.path.basename(pdf_path)
    print(f"\n Opening Slide Deck: {filename} (Resuming from page {start_page + 1})")

    doc = fitz.open(pdf_path)

    for page_num in range(start_page, len(doc)):
        page = doc[page_num]
        current_page_docs = []

        #Extract slide
        page_text = page.get_text()
        if page_text.strip():
            current_page_docs.append(
                Document(
                    page_content=page_text,
                    metadata={
                        "source": filename,
                        "page": page_num + 1,
                        "type": "slide_text"
                    }
                )
            )

        #Extract images and pass to model
        image_list = page.get_images(full=True)
        if image_list:
            if page_num % 100 == 0:
                print(f" found {len(image_list)} image(s) on page {page_num + 1}. Calling Vision AI")

            for img_index, img in enumerate(image_list):
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]

                #call summarize function
                image_description = summarize_medical_diagram(image_bytes)

                current_page_docs.append(
                    Document(
                        page_content=f"IMAGE DESCRIPTION: {image_description}",
                        metadata={
                            "source": filename,
                            "page": page_num + 1,
                            "type": "slide_image"
                        }
                    )
                )

                time.sleep(2)
        
        if current_page_docs:
            with open(output_filepath, "a", encoding="utf-8") as f:
                for d in current_page_docs:
                    source = d.metadata.get("source", "Unknown_Slide")
                    page_meta = d.metadata.get("page", "Unknown")
                    doc_type = d.metadata.get("type", "Unknown_Type")
                    
                    f.write(f"\n\n--- SOURCE: {source} | PAGE: {page_meta} | TYPE: {doc_type} ---\n\n")
                    f.write(d.page_content)
            if page_num % 100 == 0:        
                print(f" Saved Page {page_num + 1} to disk.")

# %%
def batch_process_slides(directory_path, output_filepath):
    """
    Manages the folder and handles the resume logic.
    """
    os.makedirs(os.path.dirname(output_filepath), exist_ok=True)
    
    # Figure out exactly which page we stopped at for every file
    progress_dict = get_page_level_progress(output_filepath)
    
    for filename in os.listdir(directory_path):
        if filename.endswith(".pdf"):
            full_path = os.path.join(directory_path, filename)
            
            # Find the last completed page (default to 0 if it's a new file)
            last_page = progress_dict.get(filename, 0)
            
            # Check if the file is 100% complete
            doc = fitz.open(full_path)
            total_pages = len(doc)
            doc.close()
            
            if last_page >= total_pages:
                print(f"⏩ Skipping {filename} (All {total_pages} pages already processed)")
                continue
                
            # Process starting from the next unprocessed page
            process_and_save_slides(full_path, output_filepath, start_page=last_page)
            
    print(f"\n Batch Complete! All slide data safely stored at: {output_filepath}")

# %%
# Ensure you use your absolute paths here
slides_folder = r"C:\Users\Loba\MB_ASSISTANT\data\slides"
output_text_file = r"C:\Users\Loba\MB_ASSISTANT\data\slides\extracted_slides.txt"

print("Starting Micro-Checkpoint Slide Extraction...")
batch_process_slides(slides_folder, output_text_file)
# Out:
# Starting Micro-Checkpoint Slide Extraction...
#
#  Opening Slide Deck: O and G 1 Merged.pdf (Resuming from page 1)
#  found 1 image(s) on page 1. Calling Vision AI
#  Saved Page 1 to disk.
#  found 30 image(s) on page 101. Calling Vision AI
#  Saved Page 101 to disk.

# %% [markdown]
# # Trying LLAMAINDEX to extract

# %% [markdown]
# llama-cloud documentation - https://developers.llamaindex.ai/python/cloud/

# %%
import os
import json
import asyncio
from pypdf import PdfReader, PdfWriter
from llama_parse import LlamaParse  #this has changed to llama-cloud check documentation
from dotenv import load_dotenv

load_dotenv()

# We upgrade the function to 'async def' to natively handle the event loop
async def process_with_llamaparse(input_dir, output_dir, batch_size=20):
    os.makedirs(output_dir, exist_ok=True)
    progress_file = os.path.join(output_dir, "parse_progress.json")
    
    if os.path.exists(progress_file):
        with open(progress_file, "r") as f:
            progress = json.load(f)
    else:
        progress = {}

    # Initialize parser
    parser = LlamaParse(
        api_key=os.getenv("LLAMA_CLOUD_API_KEY"),
        result_type="markdown",
        verbose=False
    )

    for filename in os.listdir(input_dir):
        if not filename.endswith(".pdf"):
            continue
            
        filepath = os.path.join(input_dir, filename)
        output_md = os.path.join(output_dir, f"{filename.replace('.pdf', '')}.md")
        
        reader = PdfReader(filepath)
        total_pages = len(reader.pages)
        
        start_page = progress.get(filename, 0)
        
        if start_page >= total_pages:
            print(f"⏩ Skipping {filename} (Already 100% processed)")
            continue
            
        print(f"\n📂 Processing {filename} (Resuming from page {start_page + 1}/{total_pages})")
        
        while start_page < total_pages:
            end_page = min(start_page + batch_size, total_pages)
            print(f"   ⏳ Sending pages {start_page + 1} to {end_page} to LlamaCloud...")
            
            writer = PdfWriter()
            for i in range(start_page, end_page):
                writer.add_page(reader.pages[i])
                
            temp_pdf = "temp_llamaparse_chunk.pdf"
            with open(temp_pdf, "wb") as f:
                writer.write(f)
            
            try:
                # THE UPGRADE: We 'await' the pure async function. No more closed event loops.
                parsed_docs = await parser.aload_data(temp_pdf)
                
                # THE FAILSAFE: If the API chokes and returns empty data, do NOT advance.
                if not parsed_docs:
                    print("   ⚠️ LlamaCloud returned empty data. Retrying in 5 seconds...")
                    await asyncio.sleep(5)
                    continue

                # Ensure we only join strings that actually have content
                chunk_text = "\n\n".join([doc.text for doc in parsed_docs if doc.text])
                
                with open(output_md, "a", encoding="utf-8") as f:
                    f.write(f"\n\n\n\n")
                    f.write(chunk_text)
                    
                start_page = end_page
                progress[filename] = start_page
                
                with open(progress_file, "w") as f:
                    json.dump(progress, f)
                    
                print(f"   ✅ Saved. Progress: {start_page}/{total_pages}")
                await asyncio.sleep(1)
                
            except Exception as e:
                error_msg = str(e).lower()
                if "429" in error_msg or "limit" in error_msg or "quota" in error_msg or "exceeded" in error_msg:
                    print("\n🛑 DAILY LLAMAPARSE LIMIT REACHED (1,000 pages).")
                    print(f"   Progress securely saved at page {start_page}. See you tomorrow!")
                    if os.path.exists(temp_pdf): os.remove(temp_pdf)
                    return 
                else:
                    print(f"   ❌ Network Error: {e}. Retrying in 10s...")
                    await asyncio.sleep(10)
                    
    if os.path.exists("temp_llamaparse_chunk.pdf"):
        os.remove("temp_llamaparse_chunk.pdf")
    print("\n🎉 ALL PDFS PROCESSED SUCCESSFULLY!")

# --- EXECUTION ---
raw_pdfs_folder = r"C:\Users\Loba\MB_ASSISTANT\data\slides" 
markdown_output_folder = r"C:\Users\Loba\MB_ASSISTANT\data\markdown_vault"

# Because Jupyter natively runs an async loop, we use 'await' right here
await process_with_llamaparse(raw_pdfs_folder, markdown_output_folder, batch_size=20)
# Out:
# C:\Users\Loba\AppData\Local\Temp\ipykernel_8740\3843872606.py:5: DeprecationWarning: The 'llama-parse' package is deprecated and will no longer receive updates. Please migrate to the new unified SDK. See https://developers.llamaindex.ai/python/cloud/llamaparse/getting_started/ and https://github.com/run-llama/llama-cloud-py/blob/main/README.md for migration instructions.
#   from llama_parse import LlamaParse
# ⏩ Skipping O and G 1 Merged.pdf (Already 100% processed)
# ⏩ Skipping Paediatrics CS edited.pdf (Already 100% processed)
#
# 🎉 ALL PDFS PROCESSED SUCCESSFULLY!

# %%
# --- EXECUTION ---
raw_pdfs_folder = r"C:\Users\Loba\MB_ASSISTANT\data\scanned_textbooks" 
markdown_output_folder = r"C:\Users\Loba\MB_ASSISTANT\data\markdown_vault"

# Because Jupyter natively runs an async loop, we use 'await' right here
await process_with_llamaparse(raw_pdfs_folder, markdown_output_folder, batch_size=20)
# Out:
# ⏩ Skipping AZUBUIKE.pdf (Already 100% processed)
#
# 📂 Processing Textbook-of-Obstetrics-and-Gynaecology-for-Medical-Students-2nd-Edition-Akin-Agboola-2006.pdf (Resuming from page 501/559)
#    ⏳ Sending pages 501 to 520 to LlamaCloud...
#    ✅ Saved. Progress: 520/559
#    ⏳ Sending pages 521 to 540 to LlamaCloud...
#    ✅ Saved. Progress: 540/559
#    ⏳ Sending pages 541 to 559 to LlamaCloud...
#    ✅ Saved. Progress: 559/559
#
# 🎉 ALL PDFS PROCESSED SUCCESSFULLY!

# %% [markdown]
# # Set up Pinecone and Ingest Data

# %% [markdown]
# Had to later do this on colab, system crashed

# %%
# Get pinecone variables
load_dotenv()
os.environ["PINECONE_API_KEY"] = os.getenv("PINECONE_API_KEY")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

# %%
#get embedding model

def download_embedding_model():
    embeddings = HuggingFaceEmbeddings(
        model_name="BAAI/bge-large-en-v1.5", 
    encode_kwargs={'normalize_embeddings': True}
    )
    return embeddings

# %%
embeddings = download_embedding_model()
# Out:
# C:\Users\Loba\AppData\Local\Temp\ipykernel_20380\4181710103.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 434.31it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
#Embedding model Dimension
len(embeddings.embed_query("hi"))
# Out:
# 1024

# %%
#markdown loader
markdown_folder = r"C:\Users\Loba\MB_ASSISTANT\data\markdown_vault"

raw_documents = []

#loop through folder for .md file
for filename in os.listdir(markdown_folder):
    if filename.endswith(".md"):
        filepath = os.path.join(markdown_folder, filename)

        with open(filepath, "r", encoding="utf-8") as file:
            content = file.read()

            raw_documents.append(
                {
                    "text": content,
                    "source": filename
                }
            )
print(f"✅ Successfully loaded {len(raw_documents)} Markdown files into memory.")
# Out:
# ✅ Successfully loaded 4 Markdown files into memory.

# %%
#Split on headers to make semantic search more robust
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]

markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
# Fallback splitter in case a textbook paragraph is too long
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150)

final_chunks = []
for doc in raw_documents:
    #split by header
    header_splits = markdown_splitter.split_text(doc["text"])

    sized_splits = text_splitter.split_documents(header_splits)

    #inject source
    for split in sized_splits:
        split.metadata["source"] = doc["source"]
    
    final_chunks.extend(sized_splits)

print(f"✅ Sliced the textbooks into {len(final_chunks)} RAG-ready chunks.")
# Out:
# ✅ Sliced the textbooks into 12468 RAG-ready chunks.

# %%
#initialize pinecone
docsearch = PineconeVectorStore.from_documents(
    documents=final_chunks,
    embedding=embeddings,
    index_name="mb-assistant"
)

# %% [markdown]
# # Define Agent tools

# %%
from pinecone import Pinecone

# %%
pinecone_api_key = os.getenv("PINECONE_API_KEY")
pinecone_index_name = os.getenv("PINECONE_INDEX_NAME")

# %%
#get embedding model

def download_embedding_model():
    embeddings = HuggingFaceEmbeddings(
        model_name="BAAI/bge-large-en-v1.5", 
    encode_kwargs={'normalize_embeddings': True}
    )
    return embeddings

# %%
embeddings = download_embedding_model()
# Out:
# C:\Users\Loba\AppData\Local\Temp\ipykernel_19172\4181710103.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 5452.31it/s]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
#Vectorestore
vectorstore = PineconeVectorStore(
    index_name = pinecone_index_name,
    embedding=embeddings
)

# %%
from langchain_core.tools import tool

# %%
from pydantic import BaseModel, Field
from langchain_core.tools import tool

class DiseaseInput(BaseModel):
    disease_name: str = Field(
        description="The specific medical disease or condition to search for."
    )

@tool(args_schema=DiseaseInput)
def search_disease_profile(disease_name: str) -> str:
    """
    Use this tool ONLY when the user asks for comprehensive details about a specific DISEASE, SYNDROME, or OBSTETRIC COMPLICATION.
    """
    # Need the query to return a detailed essay for queries on diseases
    q_patho = f"{disease_name} pathophysiology aetiology signs symptoms clinical features"
    q_invest = f"{disease_name} investigations diagnosis labs imaging criteria"
    q_manage = f"{disease_name} management treatment surgery drugs prognosis complications"
    
    # Execute 3 isolated searches (Pulling the top 2 for each category)
    # This prevents a Table of Contents from dominating the results
    docs_patho = vectorstore.similarity_search(q_patho, k=2)
    docs_invest = vectorstore.similarity_search(q_invest, k=2)
    docs_manage = vectorstore.similarity_search(q_manage, k=2)
    
    # 3. Combine the results
    all_docs = docs_patho + docs_invest + docs_manage
    
    # 4. Deduplicate (In case the same chunk scored high in multiple queries)
    unique_docs = {doc.page_content: doc for doc in all_docs}.values()
    
    if not unique_docs:
        return "NO_DATA_FOUND"
    
    #To add source and page number to returned documents
    formatted_chunks = []

    for d in unique_docs:

        source_file = d.metadata.get("source", "Unknown_File")

        page_num = d.metadata.get("page")
        page_string = f", Page: {page_num}" if page_num else ""

        chunk_text = f"[SOURCE: {source_file}{page_string}]\n{d.page_content}"
        formatted_chunks.append(chunk_text)

    return "\n\n".join(formatted_chunks)

print("✅ Search Disease Profile Function defined")
# Out:
# ✅ Search Disease Profile Function defined

# %%
response = search_disease_profile.invoke("Retinoblastoma")
print(response)
# Out:
# [SOURCE: AZUBUIKE.md]
# Retinoblastoma is a common primary ocular malignancy of childhood in the tropics (Table 75.1). It is a relatively slow-growing tumour and may be contained in the eye for months to years before causing grotesque proptosis. Because of late presentation in the tropics, most patients are either blind or can barely see when first seen. The median age is 11 months for those with bilateral tumours (30%) and about 23 months in unilateral tumours (70%). There is a genetic predisposition to retinoblastoma, of the autosomal dominant type with almost complete penetrance but the abnormal mutant allele is recessive. The retinoblastoma locus is the chromosome 13 and a deletion on the long arm of this chromosome (13q-syndrome) has been found. Prenatal diagnosis is now possible from the amniotic fluid.
#
# [SOURCE: AZUBUIKE.md]
# 1. Abramson DH. Retinoblastoma: Diagnosis and management. Cancer, 1982:32:130-140.
# 2. Kodilinye HC. Retinoblastoma, in Nigeria; problems of treatment AM J.Ophthamol, 1967; 63:469.
# 3. Olurin 0 and Williams A.O. Orbito-occular tumours in Nigeria- Cancer 1972; 30: 580.
#
# [SOURCE: AZUBUIKE.md]
# | Proptosis                   | Routine referral if symptomatic.                                                                                |
# | Pterygium                   | Expedited if Horner syndrome or 3rd nerve palsy is suspected. Refer by 3-4 months of age for congenital ptosis. |
# | Red reflex test             | Expedited to rule out cataract or retinoblastoma.                                                               |
# | Retinal detachment          | Urgent; treatment may require emergency surgery                                                                 |
# | Retinoblastoma              | Urgent; to confirm diagnosis, initiate metastatic work up and offer treatment                                   |
# | Retinopathy of prematurity  | Initial ophthalmology examination at 31-33 weeks post gestational age.                                          |
#
# [SOURCE: Textbook-of-Obstetrics-and-Gynaecology-for-Medical-Students-2nd-Edition-Akin-Agboola-2006.md]
# The usual investigation is biopsy of the lesion for histopathology. Cystoscopy, rectal examination and chest X-ray should also be carried out.
#
# [SOURCE: AZUBUIKE.md]
# General supportive treatment should be given as required. Specific treatment modalities are aimed at tumour removal or destruction. These include photocoagulation, cryopexy, radiation, chemotherapy and surgery. Surgical treatment often involves removal of the eye. This is often the only mode of treatment available in the developing countries.

# %%
@tool
def search_general_medical_fact(query: str) -> str:
    """
    Use this tool FIRST for general medical questions, statistics, anatomical facts, or single data points (e.g., 'commonest cause of childhood cancer', 'normal fetal heart rate').
    """
    docs = vectorstore.similarity_search(query, k=6)
    
    if not docs:
        return "NO_DATA_FOUND"
    
    # To return source and page if present
    formatted_chunks = []
    for d in docs:

        source_file = d.metadata.get("source", "Unknown_File")

        page_num = d.metadata.get("page")
        page_string = f", Page: {page_num}" if page_num else ""

        chunk_text = f"[SOURCE: {source_file}{page_string}]\n{d.page_content}"
        formatted_chunks.append(chunk_text)

    return "\n\n".join(formatted_chunks)

# %%
response = search_general_medical_fact.invoke("Retinoblastoma")
print(response)
# Out:
# [SOURCE: AZUBUIKE.md]
# Retinoblastoma is a common primary ocular malignancy of childhood in the tropics (Table 75.1). It is a relatively slow-growing tumour and may be contained in the eye for months to years before causing grotesque proptosis. Because of late presentation in the tropics, most patients are either blind or can barely see when first seen. The median age is 11 months for those with bilateral tumours (30%) and about 23 months in unilateral tumours (70%). There is a genetic predisposition to retinoblastoma, of the autosomal dominant type with almost complete penetrance but the abnormal mutant allele is recessive. The retinoblastoma locus is the chromosome 13 and a deletion on the long arm of this chromosome (13q-syndrome) has been found. Prenatal diagnosis is now possible from the amniotic fluid.
#
# [SOURCE: AZUBUIKE.md]
# 1. Abramson DH. Retinoblastoma: Diagnosis and management. Cancer, 1982:32:130-140.
# 2. Kodilinye HC. Retinoblastoma, in Nigeria; problems of treatment AM J.Ophthamol, 1967; 63:469.
# 3. Olurin 0 and Williams A.O. Orbito-occular tumours in Nigeria- Cancer 1972; 30: 580.
#
# [SOURCE: AZUBUIKE.md]
# Retinoblastoma usually arises from one of the layers of the retina. The tumour may be present at birth but more often presents within the first 2 years of life. Retinoblastoma, which can be unilateral or bilateral, may originate from multiple foci within an eye. Retinoblastoma results when a developing retinal cell loses the pair of the tumour suppressing genes located on the long arm of each chromosome 13. In two-thirds of the children with the tumour, this sequential mutation randomly affects one retinal cell so that the children develop uniocular and probably single tumour. Because the germ-cells are not involved, these children, if they survive, do not pass on the disease to their offspring. In a third of the children, the germ-cell is involved and the retinoblastoma is hereditary. In this instance, either the child inherited the chromosomal defect from an affected parent or a mutation occurred at the time of conception. In such children, the defect is present in every retinal and
#
# [SOURCE: Paediatrics CS edited.md]
# EBV
#
# [SOURCE: Paediatrics CS edited.md]
# Malignant eye tumour arising from the retina
# - 60% non-hereditary and unilateral
# - 15% hereditary and unilateral
# - 25% hereditary and bilateral
# Hereditary form transmitted as auto-Dominant trait with 90% penetrance
# Mut / Del of chromosome 13
#
# [SOURCE: AZUBUIKE.md]
# Many neoplastic lesions affect the orbit and eye of children. These include retinoblastoma, rhabdomyosarcoma and Burkitt's lymphoma. The commonest and most important of these is retinoblastoma.

# %%
#internet search too

ddg_search = DuckDuckGoSearchRun()

@tool
def search_internet(query: str) -> str:
    """
    Use this ONLY if the mbbs_database lacks the answer, or if the user asks for
    recent news, current guidelines, or non-medical facts.
    """
    return ddg_search.invoke(query)

# %%
response = search_internet.invoke("Retinoblastoma")
print(response)
# Out:
# 3 weeks ago -Retinoblastoma (Rb) isa rare form of cancer that rapidly develops from the immature cells of a retina, the light-detecting tissue of the eye. It is the most common primary malignant intraocular cancer in children, and 80% of retinoblastoma cases are first detected in those under 3 years old. January 16, 2026 -Retinoblastoma iscancer of the eye that begins in the retina, and is most common among children. July 15, 2025 -Retinoblastoma isthe most common type of eye cancer in children. Most children with retinoblastoma in the United States survive the cancer and go on to lead healthy lives. Children with retinoblastoma can have normal vision, play sports, and later drive cars. September 11, 2025 -Retinoblastoma isa rare cancer of the eye. It is the most common tumor affecting the eye in children, and accounts for about 3% of all childhood cancers. April 22, 2025 -Retinoblastoma (Rb) isa type of eye cancer that affects young children, mainly under the age of six. It develops in the cells of the retina.

# %%
#Pubmed search
from langchain_community.utilities.pubmed import PubMedAPIWrapper
from langchain_community.tools.pubmed.tool import PubmedQueryRun

#Pubmed Custom Wrapper
pubmed_wrapper = PubMedAPIWrapper(
    top_k_results=2,
    doc_content_chars_max=3000
)

pubmed_search = PubmedQueryRun(api_wrapper=pubmed_wrapper)

# %%
response = pubmed_search.invoke("Retinoblastoma Management")
print(response)
# Out:
# Published: 2026-02-28
# Title: Multifocal cerebral and orbital neoplastic lesions in a 2-year-old child: a case report and literature review emphasizing diagnostic uncertainty and ethical decision-making.
# Copyright Information: © 2026. The Author(s), under exclusive licence to Springer-Verlag GmbH Germany, part of Springer Nature.
# Summary::
# BACKGROUND: Multifocal cerebral and orbital neoplastic lesions in early childhood are exceptionally uncommon. Multiple lesions may occur in the context of cancer predisposition syndromes or prior irradiation; in our patient, no syndromic stigmata or prior cranial irradiation were clinically evident, but a genetic predisposition could not be excluded because molecular testing was not performed.
# CASE PRESENTATION: A previously healthy 2-year-old girl presented with chronic headache and progressive right-sided proptosis. MRI and CT identified six anatomically distinct lesions: an intraocular retinoblastoma with orbital extension (histologically confirmed), a right cerebellar lesion consistent with pilocytic astrocytoma (histologically confirmed), and multiple leptomeningeal/cortical enhancing nodules (CSF cytology-supported dissemination). Three additional lesions-right intraconal optic nerve sheath masses, a sellar/suprasellar cystic-solid lesion, and an olfactory-groove enhancing lesion-were radiologically characterized but not tissue confirmed. The child had no known family history of a cancer syndrome and no prior radiation exposure; however, inherited or mosaic predisposition could not be ruled out in the absence of genetic testing.
# CONCLUSION: This case represents an exceptionally complex pediatric presentation of multifocal cerebral and orbital neoplastic disease with mixed diagnostic certainty, rather than definitive evidence of six histologically distinct synchronous primary tumors. This case underscores that multiple spatially and pathologically discrete brain tumors can arise in a pediatric patient without identifiable risk factors. It highlights the importance of comprehensive evaluation to distinguish synchronous primaries from dissemination or a unified underlying process, and of pursuing germline/mosaic genetic assessment whenever feasible. Further study is needed to understand the etiology of such multiple tumor formations and to guide surveillance and management in similarly complex cases.
#
# Published: 2026-02-25
# Title: High-throughput screening of drug libraries identifies a new synergistic drug combination for the treatment of retinoblastoma.
# Copyright Information: Copyright: © 2026 Tseng et al. This is an open access article distributed under the terms of the Creative Commons Attribution License, which permits unrestricted use, distribution, and reproduction in any medium, provided the original author and source are credited.
# Summary::
# Retinoblastoma (RB) management often involves the combination of chemotherapeutic agents (e.g., carboplatin and etoposide) and techniques (e.g., chemotherapy and t

# %%
from pydantic import BaseModel, Field

class QuizInput(BaseModel):
    topic: str = Field(
        description="The specific Paediatrics or O&G disease to quiz the user on."
    )
    num: int = Field(description="The exact number of questions. Convert English words to integers."
        
    )

@tool(args_schema=QuizInput)
def generate_clinical_quiz(topic: str, num: int) -> str:
    """
    Use this when the user explicitly asks to be tested, quizzed, or wants practice questions on an MB3 topic.
    """
    #Use one of the tiils above to retuen context
    context = search_disease_profile.invoke({"disease_name": topic})

    if context == "NO_DATA_FOUND":
        return "INSTRUCTION TO AGENT: Tell the user you cannot generate a quiz because the topic is not in the verified MB3 database."
    return f"Generate {num} difficult, MB3-board-level multiple choice questions based strictly on this verified data. Provide the correct answers and brief rationales at the end:\n\n{context}"

# %%
# Pass the arguments as exact key-value pairs in a dictionary
response = generate_clinical_quiz.invoke({
    "topic": "Management of Retinoblastoma", 
    "num": 5
})

print(response)
# Out:
# Generate 5 difficult, MB3-board-level multiple choice questions based strictly on this verified data. Provide the correct answers and brief rationales at the end:
#
# [SOURCE: AZUBUIKE.md]
# Retinoblastoma is a common primary ocular malignancy of childhood in the tropics (Table 75.1). It is a relatively slow-growing tumour and may be contained in the eye for months to years before causing grotesque proptosis. Because of late presentation in the tropics, most patients are either blind or can barely see when first seen. The median age is 11 months for those with bilateral tumours (30%) and about 23 months in unilateral tumours (70%). There is a genetic predisposition to retinoblastoma, of the autosomal dominant type with almost complete penetrance but the abnormal mutant allele is recessive. The retinoblastoma locus is the chromosome 13 and a deletion on the long arm of this chromosome (13q-syndrome) has been found. Prenatal diagnosis is now possible from the amniotic fluid.
#
# [SOURCE: AZUBUIKE.md]
# 1. Abramson DH. Retinoblastoma: Diagnosis and management. Cancer, 1982:32:130-140.
# 2. Kodilinye HC. Retinoblastoma, in Nigeria; problems of treatment AM J.Ophthamol, 1967; 63:469.
# 3. Olurin 0 and Williams A.O. Orbito-occular tumours in Nigeria- Cancer 1972; 30: 580.
#
# [SOURCE: AZUBUIKE.md]
# | Proptosis                   | Routine referral if symptomatic.                                                                                |
# | Pterygium                   | Expedited if Horner syndrome or 3rd nerve palsy is suspected. Refer by 3-4 months of age for congenital ptosis. |
# | Red reflex test             | Expedited to rule out cataract or retinoblastoma.                                                               |
# | Retinal detachment          | Urgent; treatment may require emergency surgery                                                                 |
# | Retinoblastoma              | Urgent; to confirm diagnosis, initiate metastatic work up and offer treatment                                   |
# | Retinopathy of prematurity  | Initial ophthalmology examination at 31-33 weeks post gestational age.                                          |

# %%
toolkit = [search_disease_profile, search_general_medical_fact, search_internet, generate_clinical_quiz, pubmed_search]
print("✅ Tools loaded.")
# Out:
# ✅ Tools loaded.

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver

# %%
llm = ChatGroq(
    model="openai/gpt-oss-120b",
    api_key=os.environ["GROQ_API_KEY"],
    temperature=0.5
)

# %%
memory = MemorySaver()

# %%
from src.prompts import system_prompt

agent_executor = create_agent(
    model=llm,
    tools=toolkit,
    system_prompt=system_prompt,
    checkpointer=memory
)

# %% [markdown]
# # Invoke Query Test

# %%
config = {"configurable": {"thread_id": "mb3_study_session_002"}}

response = agent_executor.invoke(
    {"messages": [("user", "Tell me everything about Retinoblastoma.")]}, 
    config=config
)

print(response["messages"][-1].content)
# Out:
# **Definition & Epidemiology:**
# - Retinoblastoma is the most common primary intra‑ocular malignancy of childhood, especially prevalent in tropical regions of Africa.
# - It accounts for ~3 % of all childhood cancers.
# - Median age at diagnosis: **≈11 months** for bilateral disease (≈30 % of cases) and **≈23 months** for unilateral disease (≈70 %).
# - Late presentation is typical in low‑resource settings; many children are already blind or have only minimal vision when first seen.
#
# **Aetiology / Pathophysiology:**
# - **Genetic basis:** Autosomal‑dominant inheritance with almost complete penetrance; the pathogenic allele is recessive at the cellular level.
# - **RB1 tumor‑suppressor gene** located on chromosome 13q14 is mutated or deleted (13q‑syndrome).
# - Germ‑line mutations confer a hereditary form (bilateral, multifocal); somatic mutations give rise to the sporadic unilateral form.
# - Prenatal diagnosis is possible from amniotic fluid DNA testing.
#
# **Clinical Features (Signs & Symptoms):**
# - **Leukocoria** (white pupillary reflex) – the classic early sign.
# - **Strabismus** (especially in unilateral disease).
# - **Visual loss** – often profound by the time of presentation.
# - **Proptosis** and orbital extension in advanced cases (more common in the tropics due to delayed care).
# - **Secondary signs:** cataract, retinal detachment, Horner’s syndrome, third‑nerve palsy if orbital structures are involved.
#
# **Investigations:**
# 1. **Red‑reflex test** – urgent screening; abnormal reflex prompts further work‑up.
# 2. **Ophthalmic examination under anesthesia** with indirect ophthalmoscopy to delineate tumour size, location, and laterality.
# 3. **Imaging:**
#    - **B‑scan ultrasonography** (high‑gain “calcified” lesions).
#    - **MRI of the brain and orbits** (preferred to CT to avoid radiation).
# 4. **Systemic staging:**
#    - **Chest X‑ray, abdominal ultrasound/CT** for metastatic spread (lung, bone, CNS).
#    - **Bone scan** if indicated.
# 5. **Histopathology** (biopsy is rarely performed pre‑treatment; enucleated specimen provides definitive diagnosis).
#
# **Management:**
# - **Goal:** Preserve life first, then eye, then vision.
# - **Eye‑saving modalities (when tumour is limited):**
#   - **Laser photocoagulation** (for small peripheral tumours).
#   - **Cryotherapy** (for peripheral lesions ≤3 mm).
#   - **Thermo‑coagulation / thermotherapy.**
#   - **Intra‑arterial chemotherapy (IAC)** – delivers high‑dose drug directly to the ophthalmic artery.
#   - **Intravitreal chemotherapy** for vitreous seeds.
# - **Systemic chemotherapy** (chemoreduction) – vincristine, etoposide, carboplatin regimen; reduces tumour size to allow focal therapy.
# - **Radiation therapy** (external beam) – reserved for cases where chemotherapy/focal therapy fail; limited by risk of secondary malignancies.
# - **Surgical:**
#   - **Enucleation** (removal of the eye) – indicated for large, non‑salvageable tumours, especially with extra‑ocular extension.
#   - **Orbital exenteration** for extensive orbital disease.
# - **Supportive care:** pain control, psychosocial support, visual rehabilitation when possible.
#
# **Complications & Prognosis:**
# - **Early‑stage disease** (intra‑ocular, no metastasis) has >95 % survival with globe‑preserving therapy.
# - **Advanced disease** (extra‑ocular extension, metastasis) carries a poorer prognosis; survival drops to 30‑50 % in many African centres.
# - **Late complications:**
#   - **Secondary malignancies** (osteosarcoma, soft‑tissue sarcoma) especially after radiation.
#   - **Phthisis bulbi** (shrunken, non‑functional eye) after enucleation or severe disease.
#   - **Cosmetic and psychosocial impact** of enucleation; prosthetic fitting is essential.
#
# ---
#
# **Suggested follow‑up question for deeper learning:**
# *How does the management algorithm differ between hereditary (bilateral) and sporadic (unilateral) retinoblastoma, and what surveillance strategies are recommended for at‑risk family members?*

# %%
config = {"configurable": {"thread_id": "mb3_study_session_013"}}

response = agent_executor.invoke(
    {"messages": [("user", "What is congenital heart disease?")]}, 
    config=config
)

print(response["messages"][-1].content)
# Out:
# **Definition & Epidemiology:**
# Congenital heart disease (CHD) refers to any structural abnormality of the heart or great vessels that is present at birth. It is the commonest congenital malformation worldwide, affecting roughly **6‑10 per 1 000 live‑births** (Ferencz C et al., 1985). In Nigeria, early hospital‑based series reported a prevalence of about **8 per 1 000 live‑births** (Antia AU, 1974). The spectrum ranges from simple isolated lesions (e.g., small ventricular septal defect) to complex cyanotic heart disease (e.g., Tetralogy of Fallot).
#
# **Aetiology / Pathophysiology:**
# - **Genetic factors:** Chromosomal anomalies (e.g., Down syndrome), single‑gene mutations, and familial inheritance patterns (Hoffman JIE, 1990).
# - **Environmental / Maternal factors:** Maternal diabetes, rubella infection, teratogenic drugs (e.g., isotretinoin), and maternal smoking or alcohol use.
# - **Pathophysiology:** Abnormal cardiac morphogenesis leads to one or more of the following:
#   1. **Septal defects** (ASD, VSD, PDA) → left‑to‑right shunts → volume overload of pulmonary circulation.
#   2. **Obstructive lesions** (coarctation, pulmonary stenosis) → pressure overload of upstream chambers.
#   3. **Cyanotic lesions** (tetralogy, transposition) → right‑to‑left shunt or mixing → systemic hypoxaemia.
#   The resultant haemodynamic burden can precipitate congestive heart failure (CHF), pulmonary hypertension, and growth failure.
#
# **Clinical Features (Signs & Symptoms):**
# - **General:** Poor feeding, failure to thrive, tachypnoea, diaphoresis with feeds, recurrent chest infections.
# - **Specific murmurs:** Harsh holosystolic murmur (large VSD), continuous “machinery” murmur (PDA), systolic ejection murmur (ASD).
# - **Cyanosis:** Central cyanosis, clubbing in cyanotic lesions.
# - **Physical findings:** Bounding peripheral pulses (large PDA), diminished femoral pulses (coarctation), displaced apex, cardiomegaly on inspection.
# - **Compensatory signs:** Hepatomegaly, peripheral oedema in advanced CHF.
#
# **Investigations:**
# 1. **History & thorough physical examination** – cornerstone of initial assessment.
# 2. **Electrocardiogram (ECG):** May show left‑ventricular hypertrophy (large left‑to‑right shunts) or right‑ventricular hypertrophy (cyanotic lesions).
# 3. **Chest X‑ray:** Cardiomegaly, increased pulmonary vascular markings, “boot‑shaped” heart in Tetralogy.
# 4. **2‑D Echocardiography (with colour Doppler):** Gold‑standard for anatomical delineation, shunt quantification, valve assessment.
# 5. **Cardiac catheterisation:** Reserved for complex lesions, pre‑operative haemodynamic assessment, or interventional closure.
#
# **Management:**
# - **Medical (palliative):**
#   - **Heart‑failure control:** Diuretics, ACE‑inhibitors, digoxin as needed.
#   - **Infection prophylaxis:** Prompt treatment of chest infections; infective endocarditis prophylaxis when indicated.
#   - **Nutritional support:** High‑calorie diets to counter growth failure.
# - **Surgical / Interventional:**
#   - **Definitive repair:** Patch closure of ASD/VSD, ligation or device closure of PDA, complete repair of complex cyanotic lesions.
#   - **Palliation (when early repair is high‑risk):** Pulmonary artery banding, systemic‑to‑pulmonary shunts.
#   - **Outcomes:** In experienced centres, operative mortality is **5‑10 %**; long‑term prognosis depends on residual valve dysfunction and pulmonary hypertension.
#
# **Complications & Prognosis:**
# - **Short‑term:** Acute CHF, pulmonary over‑circulation, severe infections, growth retardation.
# - **Long‑term:** Pulmonary arterial hypertension, arrhythmias, residual valve regurgitation, Eisenmenger syndrome (irreversible pulmonary hypertension with right‑to‑left shunt), endocarditis.
# - **Prognosis:** With timely diagnosis and appropriate surgical repair, > 90 % of children with simple lesions survive into adulthood with good functional status. Complex lesions carry higher morbidity and require lifelong cardiology follow‑up.
#
# ---
#
# **Suggested follow‑up question for deeper learning:**
# *How does the timing of surgical repair (neonatal vs. later infancy) influence the development of pulmonary vascular disease in children with large left‑to‑right shunts?*

# %%
# Test with chat

#Generate random session ID
session_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": session_id}}

print("✅ MB3 Clinical Assistant Online. Type 'exit' or 'quit' to end the session.")
print("-" * 60)

while True:
    #User input
    user_input = input("\nYou: ")

    #Input to stop chat
    if user_input.lower() in ["exit", "quit"]:
        print("\nEnding study session. Good luck with your MB3 exams!")
        break

    print(f"\n User: \n{user_input}")
    
    try:
        #invoke Agent
        response = agent_executor.invoke(
            {"messages": [("user", user_input)]},
            config=config
        )

        #Extract and print final message
        final_answer = response["messages"][-1].content
        print(f"\n🤖 MB3 assistant:\n{final_answer}")
        print("-" * 60)
    
    except Exception as e:
        print(f"\n❌ Error during execution: {e}")
# Out:
# ✅ MB3 Clinical Assistant Online. Type 'exit' or 'quit' to end the session.
# ------------------------------------------------------------
#
# Ending study session. Good luck with your MB3 exams!

# %% [markdown]
# # STREAMING CHATS TEST

# %%
# CELL: The Unfiltered Stream Diagnostic
import uuid

# 1. Force a completely clean memory slate
config = {"configurable": {"thread_id": str(uuid.uuid4())}}
prompt = "Tell me about Congenital Heart Diseases."

print(f"User: {prompt}\n")
print("🚀 Launching Unfiltered Stream...\n")

try:
    # 2. Start the stream
    stream = agent_executor.stream(
        {"messages": [("user", prompt)]}, 
        config=config,
        stream_mode="messages"
    )

    # 3. Print EVERYTHING. No filters. 
    for chunk, metadata in stream:
        # Print the type of message (ai, human, tool) and its raw content
        print(f"[{chunk.type.upper()}] Content: {repr(chunk.content)}")
        
        # If it's trying to run a tool, expose the tool name
        if hasattr(chunk, "tool_calls") and chunk.tool_calls:
            print(f"   ⚙️ HIDDEN TOOL CALL DETECTED: {chunk.tool_calls[0]['name']}")

except Exception as e:
    print(f"\n❌ CRASH: {e}")

print("\n✅ Stream Complete.")
# Out:
# User: Tell me about Congenital Heart Diseases.
#
# 🚀 Launching Unfiltered Stream...
#
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
#    ⚙️ HIDDEN TOOL CALL DETECTED: search_disease_profile
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [TOOL] Content: '[SOURCE: AZUBUIKE.md]\n1. Antia AU. Congenital heart disease in Nigeria Arch Dis Child 1974;49:36-39.\n2. Ferencz C. Rubin JD, McCarter RJ et al. Congenital heart disease: prevalence at livebirth. Am J Epidemiol 1985;121:31-36.\n3. Okoroma EO, Ihenacho HNC, Anyanwn CH, Udekwu FAO. Congenital Heart disease experience with the first 70 documented cases at the University of Nigeria Teaching Hospital Enugu.\n4. Niq Med J 1978:8:491.\n5. Park MK. The Pediatric Cardiology Handbook. Mosby Year Book Publishers 1991.\n6. Steinbenger J, Moller JH, Berry JM, RDMS, Sinaiko AR. Echocardiographic diagnosis of heart disease in apparently healthy adolescents. Pediatrics 2000;105:815-818.\n7. Hoffman. JIE. Congenital heart disease incidence and inheritance Pediatr Clin North Am 1990:37:25-43.\n8. Nora JJ. Causes of congenital heart disease: old and new modes, mechanisms and models. Am Heart J 1993;125:1409-1419.\n\n[SOURCE: AZUBUIKE.md]\nCertain rare and complex defects like single atrium, hypoplastic left heart syndrome will not be discussed here. The defects in the table will be discussed under the simple format of general description, anatomy and pathophysiology, clinical presentation, laboratory investigations and treatment. It is important to bear in mind that the subject of cardiac treatment is a very dynamic one. Consequently, treatment described for some defects below may undergo rapid change or modification with time.  \nFigure 40.1. Schematic illustration of a normal heart.\n\n[SOURCE: AZUBUIKE.md]\nAdequate evaluation of the patient suspected to have heart disease begins with a good history and a thorough physical examination of the patient. In addition, certain laboratory investigations, like electrocardiogram and chest X-ray, are invaluable. In fortunate centres, which have the facilities of 2-dimensional echocardiography and cardiac catheterization, definitive diagnosis of the cardiac defects can be established in most cases.\n\n[SOURCE: AZUBUIKE.md]\nThese are carried out, not so much to confirm the diagnosis of heart failure, but more importantly, to ascertain the cause, determine the severity and monitor the response to treatment. Chest X-ray, electrocardiogram (ECG) and where available, arterial blood gases, echocardiography and cardiac catheterisation, are useful in confirming the nature of intrinsic cardiac lesions. Unfortunately, the latter three facilities are not always available in most developing countries. Other investigations that may be necessary include full blood counts, erythrocyte sedimentation rate (ESR), antistreptolysin-O titre (ASOT), blood cultures, blood chemistry, etc. depending on the suspected cause.  \n| Age (Years) | Digitalization (mg/kg/24hr) | Maintenance (mg/kg/24hr) |\n| ----------- | --------------------------- | ------------------------ |\n| < 1         | 0.04-0.06                   | 0.01                     |\n| 1/12-2yrs   | 0.04-0.08                   | 0.01 - 0.02              |\n\n[SOURCE: AZUBUIKE.md]\nMedical management is limited to controlling congestive heart failure, treating any chest infections when they occur and maintaining adequate nutrition. Infective endocarditis prophylaxis is also necessary when indicated. Definitive treatment for the defect is surgical. In the very young patient with intractable heart failure, palliative pulmonary artery banding can be done to delay early development of pulmonary vascular disease and to avoid the very high mortality attendant on total correction in this age group. Total correction, which involves complicated surgery, can be done later in life and comprises in the simplest terms, patch closure of the atrial septal defect, the ventricular septal defect and reconstruction of the AV valve. Mortality is around 5-10% in good hands and the long-term results are influenced by the degree of residual mitral valve regurgitation and pulmonary hypertension.\n\n[SOURCE: AZUBUIKE.md]\nMedical treatment for the patient with a ventricular  ...
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: '**'
# [AIMESSAGECHUNK] Content: 'Cong'
# [AIMESSAGECHUNK] Content: 'en'
# [AIMESSAGECHUNK] Content: 'ital'
# [AIMESSAGECHUNK] Content: ' Heart'
# [AIMESSAGECHUNK] Content: ' Diseases'
# [AIMESSAGECHUNK] Content: ' ('
# [AIMESSAGECHUNK] Content: 'CH'
# [AIMESSAGECHUNK] Content: 'D'
# [AIMESSAGECHUNK] Content: ')**'
# [AIMESSAGECHUNK] Content: '  \n\n'
# [AIMESSAGECHUNK] Content: '**'
# [AIMESSAGECHUNK] Content: 'Definition'
# [AIMESSAGECHUNK] Content: ' &'
# [AIMESSAGECHUNK] Content: ' Epidemi'
# [AIMESSAGECHUNK] Content: 'ology'
# [AIMESSAGECHUNK] Content: ':**'
# [AIMESSAGECHUNK] Content: '  \n'
# [AIMESSAGECHUNK] Content: 'Cong'
# [AIMESSAGECHUNK] Content: 'en'
# [AIMESSAGECHUNK] Content: 'ital'
# [AIMESSAGECHUNK] Content: ' heart'
# [AIMESSAGECHUNK] Content: ' disease'
# [AIMESSAGECHUNK] Content: ' refers'
# [AIMESSAGECHUNK] Content: ' to'
# [AIMESSAGECHUNK] Content: ' structural'
# [AIMESSAGECHUNK] Content: ' abnormalities'
# [AIMESSAGECHUNK] Content: ' of'
# [AIMESSAGECHUNK] Content: ' the'
# [AIMESSAGECHUNK] Content: ' heart'
# [AIMESSAGECHUNK] Content: 

# [AIMESSAGECHUNK] Content: '‑'
# [AIMESSAGECHUNK] Content: 'rich'
# [AIMESSAGECHUNK] Content: ' centre'
# [AIMESSAGECHUNK] Content: ' with'
# [AIMESSAGECHUNK] Content: ' full'
# [AIMESSAGECHUNK] Content: ' cardiac'
# [AIMESSAGECHUNK] Content: ' catheter'
# [AIMESSAGECHUNK] Content: 'isation'
# [AIMESSAGECHUNK] Content: ' facilities'
# [AIMESSAGECHUNK] Content: ' and'
# [AIMESSAGECHUNK] Content: ' a'
# [AIMESSAGECHUNK] Content: ' typical'
# [AIMESSAGECHUNK] Content: ' district'
# [AIMESSAGECHUNK] Content: ' hospital'
# [AIMESSAGECHUNK] Content: ' in'
# [AIMESSAGECHUNK] Content: ' sub'
# [AIMESSAGECHUNK] Content: '‑'
# [AIMESSAGECHUNK] Content: 'S'
# [AIMESSAGECHUNK] Content: 'aharan'
# [AIMESSAGECHUNK] Content: ' Africa'
# [AIMESSAGECHUNK] Content: '?'
# [AIMESSAGECHUNK] Content: '*'
# [AIMESSAGECHUNK] Content: ''
# [AIMESSAGECHUNK] Content: ''
#
# ✅ Stream Complete.

# %%
# CELL 8: The Final MB3 Interactive Terminal
import uuid

def get_new_config():
    return {"configurable": {"thread_id": str(uuid.uuid4())}}

config = get_new_config()

print("✅ MB3 Clinical Assistant Online . Type 'exit' to end.")
print("-" * 60)

while True:
    user_input = input("\nYou: ")

    if user_input.lower() in ["exit", "quit"]:
        print("\nEnding study session. Good luck with your MB3 exams!")
        break

    print(f"\nUser: \n{user_input}")
    print("\n🤖 MB3 Assistant: ", end="", flush=True) 
    
    try:
        for chunk, metadata in agent_executor.stream(
            {"messages": [("user", user_input)]},
            config=config,
            stream_mode="messages"
        ):
            # --- 1. THE TOOL CALL INDICATOR ---
            if hasattr(chunk, "tool_calls") and chunk.tool_calls:
                tool_name = chunk.tool_calls[0].get("name", "Unknown Tool")
                print(f"\n[⚙️ Running Tool: {tool_name}...] \n", end="", flush=True)
            
            # --- 2. THE BULLETPROOF TEXT FILTER ---
            # We check the actual Python class name instead of the fragile .type attribute
            elif "AI" in chunk.__class__.__name__ and chunk.content:
                if isinstance(chunk.content, str):
                    print(chunk.content, end="", flush=True)
                elif isinstance(chunk.content, list) and len(chunk.content) > 0 and "text" in chunk.content[0]:
                    print(chunk.content[0]["text"], end="", flush=True)

        print("\n" + "-" * 60)
    
    except Exception as e:
        print(f"\n❌ Error during execution: {e}")
        print("🔄 Wiping corrupted memory and resetting thread...")
        config = get_new_config()
# Out:
# ✅ MB3 Clinical Assistant Online . Type 'exit' to end.
# ------------------------------------------------------------
#
# User:
# Malaria
#
# 🤖 MB3 Assistant:
# [⚙️ Running Tool: search_disease_profile...]
# **Definition & Epidemiology:**
# Malaria is an acute febrile illness caused by intra‑erythrocytic parasites of the genus *Plasmodium* (most commonly *P. falciparum*, *P. vivax*, *P. malariae*, and *P. ovale*). Transmission occurs through the bite of infected *Anopheles* mosquitoes. In sub‑Saharan Africa, malaria remains the leading cause of childhood morbidity and mortality, with the highest burden in children aged 6 months to 2 years.
#
# **Aetiology / Pathophysiology:**
# - **Life‑cycle phases:** Exo‑erythrocytic (liver), erythrocytic (blood), and sporogonic (mosquito) stages. Clinical disease arises during the erythrocytic stage when schizonts rupture, releasing merozoites and parasite‑derived toxins.
# - **Cytokine storm:** Release of parasite and red‑cell membrane products triggers cytokines (TNF‑α, IL‑1, IL‑6) that produce fever, rigors, and systemic manifestations.
# - **Severe disease mechanisms:** High parasitaemia (>5 % of erythrocytes or >250 000 parasites/µL) leads to sequestration of infected red cells in microvasculature, causing cerebral malaria, severe anaemia, metabolic acidosis, renal and hepatic failure.
#
# **Clinical Features (Signs & Symptoms):**
# - **Typical paroxysmal fever** with rigors, chills, and sweating.
# - **General symptoms:** Headache, malaise, anorexia, nausea/vomiting, diarrhoea, myalgia, arthralgia, and fatigue.
# - **Paediatric nuances:** Cough, behavioural changes (fretfulness, excessive crying), drowsiness, sleep disturbance, pallor, jaundice, hepatomegaly, splenomegaly (often non‑tender).
# - **Severe malaria (6 months–2 years):** Hyperpyrexia, vomiting, seizures, impaired consciousness/coma, severe anaemia, hypoglycaemia, lactic acidosis, renal or hepatic failure, prostration.
#
# **Investigations:**
# - **Peripheral blood smear (Giemsa stain):** Thick film for parasite density; thin film for species identification. *P. falciparum* smears are best taken during a febrile paroxysm.
# - **Rapid diagnostic tests (RDTs):** Detect HRP‑2 or pLDH antigens; useful where microscopy is unavailable.
# - **Serology:** Indicates past exposure; not reliable for acute diagnosis.
# - **Additional labs in severe disease:** Full blood count (haemoglobin, platelets), blood glucose, renal and liver function tests, lactate, arterial blood gases.
#
# **Management:**
# 1. **Confirm diagnosis** (microscopy or RDT) and determine species.
# 2. **First‑line antimalarials (per WHO/ national guidelines):**
#    - *Uncomplicated* *P. falciparum*: Artemisinin‑based combination therapy (ACT) – e.g., artemether‑lumefantrine, artesunate‑amodiaquine.
#    - *Uncomplicated* non‑falciparum: Chloroquine (if sensitivity retained) or ACT.
#    - *Severe* malaria: Intravenous artesunate (preferred) followed by a full ACT course once the patient can tolerate oral medication.
# 3. **Supportive care:**
#    - Blood transfusion for severe anaemia.
#    - Intravenous dextrose for hypoglycaemia.
#    - Fluid resuscitation for shock or acidosis (cautiously in severe malaria).
#    - Anticonvulsants for seizures.
#    - Antipyretics (paracetamol).
# 4. **Adjuncts:** Parenteral antibiotics if bacterial co‑infection is suspected; monitor for complications (renal, hepatic, pulmonary).
#
# **Complications & Prognosis:**
# - **Life‑threatening complications:** Cerebral malaria, severe anaemia, hypoglycaemia, metabolic acidosis, acute renal failure, pulmonary oedema, and multi‑organ dysfunction.
# - **Risk factors for fatal outcome:** Hyperparasitaemia, deep coma, repeated convulsions, decerebration, severe anaemia, hypoglycaemia, lactic acidosis, renal failure.
# - **Prognosis:** With prompt ACT and appropriate supportive care, mortality in uncomplicated malaria is <1 %. In severe malaria, mortality ranges from 10–20 % in resource‑limited settings, but early IV artesunate reduces deaths by ~35 % compared with quinine.
#
# ---
#
# **Suggested follow‑up question:**
# *What are the specific WHO recommendations for the management of severe malaria in children under five, and how do they differ from adult treatment protocols?*
# ------------------------------------------------------------
#
# User:
# what are the recent findings on malaria
#
# 🤖 MB3 Assistant:
# [⚙️ Running Tool: pub_med...]

# %% [markdown]
# ## Streaming Debugging

# %%
# CELL: Single Prompt Stream Test
config = {"configurable": {"thread_id": "mb3_minimal_test_001"}}
prompt = "Tell me everything about Retinoblastoma."

print(f"User: {prompt}\n")
print("🤖 Agent: ", end="")

# You must use a for-loop to unpack the generator in real-time
for chunk, metadata in agent_executor.stream(
    {"messages": [("user", prompt)]}, 
    config=config,
    stream_mode="messages"
):
    # The absolute minimal filter: Is it the AI, and does it have text?
    if chunk.type == "ai" and chunk.content:
        # Assuming string output based on our Naked Stream test
        print(chunk.content, end="", flush=True)

print("\n\n✅ Stream Complete.")
# Out:
# User: Tell me everything about Retinoblastoma.
#
# 🤖 Agent:
#
# ✅ Stream Complete.

# %%
# CELL: THE NAKED STREAM DEBUGGER
import uuid

# Your LLM and agent are already defined correctly above this.
config = {"configurable": {"thread_id": str(uuid.uuid4())}}
test_prompt = "Tell me about Retinoblastoma."

print("🚀 Launching Naked Stream for gpt-oss-120b...")

try:
    for chunk, metadata in agent_executor.stream(
        {"messages": [("user", test_prompt)]},
        config=config,
        stream_mode="messages"
    ):
        # 1. Print the exact class type and the raw representation of the content
        print(f"\n[RAW] Type: {type(chunk).__name__} | Content: {repr(chunk.content)}")
        
        # 2. Hunt for hidden data structures (like CoT reasoning fields)
        if hasattr(chunk, "response_metadata") and chunk.response_metadata:
            print(f"      Metadata: {chunk.response_metadata}")
            
        # 3. Verify how tool calls are structured
        if hasattr(chunk, "tool_calls") and chunk.tool_calls:
            print(f"      Hidden Tool Call: {chunk.tool_calls}")

    print("\n✅ Stream Finished.")

except Exception as e:
    print(f"\n❌ CRASH: {e}")
# Out:
# 🚀 Launching Naked Stream for gpt-oss-120b...
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'model_provider': 'groq'}
#       Hidden Tool Call: [{'name': 'search_disease_profile', 'args': {'disease_name': 'Retinoblastoma'}, 'id': 'fc_851a505c-33a9-4082-a7dd-9f876c78a22b', 'type': 'tool_call'}]
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'finish_reason': 'tool_calls', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_87b3c396db', 'service_tier': 'on_demand'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#
# [RAW] Type: ToolMessage | Content: '[SOURCE: AZUBUIKE.md]\nRetinoblastoma is a common primary ocular malignancy of childhood in the tropics (Table 75.1). It is a relatively slow-growing tumour and may be contained in the eye for months to years before causing grotesque proptosis. Because of late presentation in the tropics, most patients are either blind or can barely see when first seen. The median age is 11 months for those with bilateral tumours (30%) and about 23 months in unilateral tumours (70%). There is a genetic predisposition to retinoblastoma, of the autosomal dominant type with almost complete penetrance but the abnormal mutant allele is recessive. The retinoblastoma locus is the chromosome 13 and a deletion on the long arm of this chromosome (13q-syndrome) has been found. Prenatal diagnosis is now possible from the amniotic fluid.\n\n[SOURCE: AZUBUIKE.md]\n1. Abramson DH. Retinoblastoma: Diagnosis and management. Cancer, 1982:32:130-140.\n2. Kodilinye HC. Retinoblastoma, in Nigeria; problems of treatment AM J.Ophthamol, 1967; 63:469.\n3. Olurin 0 and Williams A.O. Orbito-occ

#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'gn'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'osis'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ':**'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' Excellent'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' (>'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '95'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '\u202f'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '%'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' survival'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ')'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' when'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' diagnosed'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' early'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' and'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' treated'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' promptly'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ';'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' drops'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' dramatically'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' with'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' extra'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '‑'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'ocular'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' extension'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' or'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' metastatic'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' disease'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '.'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '  \n'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '-'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' **'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'Long'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '‑'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'term'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' risks'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ':**'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' Increased'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' incidence'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' of'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' secondary'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' cancers'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' in'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' hereditary'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' carriers'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ','
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' necess'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'itating'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' lifelong'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' monitoring'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '.\n\n'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '---\n\n'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '**'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'Suggested'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' follow'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '‑'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'up'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' question'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' for'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' deeper'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' learning'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ':**'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '  \n'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '*'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'How'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' does'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' the'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' management'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' strategy'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' differ'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' between'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' hereditary'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' bilateral'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' ret'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'in'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'oblast'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'oma'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' and'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' spor'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'adic'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' unilateral'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' disease'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ','
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' and'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' what'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' are'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' the'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' implications'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' for'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' genetic'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' counseling'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' and'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' long'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '‑'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: 'term'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ' surveillance'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '?'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: '*'
#       Metadata: {'model_provider': 'groq'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#       Metadata: {'finish_reason': 'stop', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_854fa9be4c', 'service_tier': 'on_demand'}
#
# [RAW] Type: AIMessageChunk | Content: ''
#
# ✅ Stream Finished.

# %% [markdown]
# # Voice Test

# %%
# To process voice inputs we need a voice model
import os
from groq import Groq

groq_client = Groq(api_key=os.environ["GROQ_API_KEY"])
def transcribe_audio(audio_file_path):
    """
    Takes an audio file and returns the transcribed text.
    """

    # Open the file in binry read mode("rb")
    with open(audio_file_path, "rb") as file:
        transcription = groq_client.audio.transcriptions.create(
            file=(audio_file_path, file.read()),
            model="whisper-large-v3",
            response_format="json",
        )
    
    return transcription.text

# %%
#Live Voice Transcription
from groq import Groq
import os

groq_client = Groq(api_key=os.environ["GROQ_API_KEY"])

def transcribe_live_audio(audio_bytes, temp_filename="live_recording.wav"):
    """
    Takes raw audio bytes directly from a browser microphone and transcribes them.
    No hard drive saving required.
    """
    print("🎙️ Processing live audio stream from RAM...")

    transcription = groq_client.audio.transcriptions.create(
        file=(temp_filename, audio_bytes),
        model="whisper-large-v3",
        response_format="json",
    )

    return transcription.text

# %% [markdown]
# # Image test

# %%
import base64
from groq import Groq

def analyze_image(image_path, clinical_question):
    """
    Converts an image to Base64 and asks the Vision model a question about it.
    """

    # Convert the image to a Base64  string
    with open(image_path, "rb") as image_file:
        base63_image = base64.b64encode(image_file.read()).decode("utf-8")

    response = groq_client.chat.completions.create(
        model="meta-llama/llama-4-scout-17b-16e-instruct",
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": clinical_question},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/jped;base64,{base64_image}"
                        }
                    }
                ]
            }
        ],
        temperature=0.2
    )

    return response.choices[0].message.content

# %%
import base64

def analyze_live_image(image_bytes, clinical_question):
    """
    Converts raw image bytes from a browser camera directly to Base64 
    and asks the Vision model a question.
    """
    print("👁️ Encoding live camera frame from RAM...")

    base64_image = base64.b64encode(image_bytes).decode('utf-8')

    response = groq_client.chat.completions.create(
        model="meta-llama/llama-4-scout-17b-16e-instruct",
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": clinical_question},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/jpeg;base64,{base64_image}"
                        }
                    }
                ]
            }
        ],
        temperature=0.2 
    )
    
    return response.choices[0].message.content

# %% [markdown]
# # Extract PDF

# %%
import fitz
def extract_text_from_pdf(pdf_path):
    """
    Extracts text from a short PDF file.
    """

    doc = fitz.open(pdf_path)
    extracted_text = ""

    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        extracted_text += page.get_text("text") + "\n\n"
    
    return extracted_text
